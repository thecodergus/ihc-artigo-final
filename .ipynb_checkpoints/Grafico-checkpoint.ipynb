# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Feedback IHC heatmaps.csv')

# %%
df['Carimbo de data/hora'] = pd.to_datetime(df['Carimbo de data/hora'])

# %%
df["hora"] = df['Carimbo de data/hora'].dt.time

# %%
df.pop("Carimbo de data/hora")
# Out:
# 0   2022-12-06 16:16:52+03:00
# 1   2022-12-06 16:33:15+03:00
# 2   2022-12-06 16:49:37+03:00
# 3   2022-12-07 15:45:57+03:00
# 4   2022-12-07 15:47:51+03:00
# 5   2022-12-07 15:58:12+03:00
# 6   2022-12-07 15:58:24+03:00
# 7   2022-12-07 16:24:17+03:00
# 8   2022-12-07 16:24:35+03:00
# 9   2022-12-07 16:43:39+03:00
# Name: Carimbo de data/hora, dtype: datetime64[ns, pytz.FixedOffset(180)]

# %%
df = df.sort_values(by="hora")

# %%
df[3:]
# Out:
#    O design do jogo é atraente.  \
# 0                             4
# 7                             5
# 8                             5
# 1                             5
# 9                             5
# 2                             4
#
#    O jogo contribuiu para a minha aprendizagem na disciplina.  \
# 0                                                  5
# 7                                                  5
# 8                                                  4
# 1                                                  5
# 9                                                  4
# 2                                                  5
#
#    O jogo evolui num ritmo adequado e não fica monótono — oferece novos obstáculos, situações ou variações de atividades.  \
# 0                                                  2
# 7                                                  5
# 8                                                  4
# 1                                                  4
# 9                                                  5
# 2                                                  5
#
#    O conteúdo do jogo está conectado com outros conhecimentos que eu já possuía.  \
# 0                                                  5
# 7                                                  3
# 8                                                  4
# 1                                                  5
# 9                                                  5
# 2                                                  3
#
#    O jogo forneceu feedback constante dos meus acertos e erros durante e ao final.  \
# 0                                                  3
# 7                                                  4
# 8                                                  5
# 1                                                  5
# 9                                                  3
# 2                                                  5
#
#    Eu gostei do jogo e não me senti ansioso ou entediado por causa dele.  \
# 0                                                  4
# 7                                                  5
# 8                                                  3
# 1                                                  5
# 9                                                  4
# 2                                                  5
#
#    A organização das informações na tela está clara e objetiva  \
# 0                                                5.0
# 7                                                5.0
# 8                                                NaN
# 1                                                5.0
# 9                                                5.0
# 2                                                4.0
#
#    Esquema de pontuação de acertos e erros foi feita de forma justa  \
# 0                                                  5
# 7                                                  5
# 8                                                  5
# 1                                                  5
# 9                                                  5
# 2                                                  5
#
#    Foi fácil entender o jogo.  O tempo de jogo foi satisfatório.      hora
# 0                           5                                  4  16:16:52
# 7                           4                                  5  16:24:17
# 8                           5                                  5  16:24:35
# 1                           5                                  5  16:33:15
# 9                           5                                  5  16:43:39
# 2                           5                                  5  16:49:37
